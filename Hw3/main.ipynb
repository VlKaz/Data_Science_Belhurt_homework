# %%
import sqlite3
from mod import (create_table, clear_table, calculations, visual)

def main():
    # Создание SQLite
    filedata = 'data/automobile.csv'
    filedb = 'data/auto.db'
    create_table(filedata,filedb)
    # Удоляем строки если в колонке лошадиные силы есть "?"(это надо чтобы позже построить график)
    clear_table(filedb)
    # Занимаемся подсчетами всякого разного формируя запросы к SQLite
    calculations(filedb)
    # Выводим графики 
    visual(filedb)
        
if __name__ == "__main__":
    main()
# Out:
# Таблица успешно создана.
# Средняя стоимость седанов: 14546 в $
# Средняя стоимость универсалов: 12500 в $
# На каком топливе и сколько: [('diesel', 20), ('gas', 180)]
# Самая дорогая машина: mercedes-benz стоимостью 45400 $
# Самая дешовая машина: subaru стоимостью 5118 $
